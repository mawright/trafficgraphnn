# %% [markdown]
# TODO:
# - write parser that only provides the data for one cycle are used in an array
# - make outer loop for num_phases and inner loop dor lanes
# - complete functions that calculate breakpoints, estimate queue and plot for each lane

# %%
from trafficgraphnn.sumo_network import SumoNetwork
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd


#sn = SumoNetwork(
#    'data/networks/one_intersection_3lanes/one_intersection_3lanes.net.xml', routefile='data/networks/one_intersection_3lanes/one_intersection_3lanes_rand_routes.routes.xml',
#    lanewise=True, addlfiles=['data/networks/one_intersection_3lanes/one_intersection_3lanes_additionals.add.xml', 'data/networks/one_intersection_3lanes/tls_output.add.xml']
#)

#sn = SumoNetwork(
#    'data/networks/new_test/new_test.net.xml', routefile='data/networks/new_test/new_test_rand_routes.routes.xml',
#    lanewise=True, addlfiles=['data/networks/new_test/new_test_additionals.add.xml', 'data/networks/new_test/tls_output.add.xml']
#)

#sn = SumoNetwork(
#    'data/networks/liu_network/liu_network.net.xml', routefile='data/networks/liu_network/liu_network_rand_routes.routes.xml',
#    lanewise=True, addlfiles=['data/networks/liu_network/liu_network_additionals.add.xml', 'data/networks/liu_network/tls_output.add.xml']
#)

# with modified traffic lights
#sn = SumoNetwork(
#    'data/networks/smallnet/smallnet.net.xml', routefile='data/networks/smallnet/smallnet_rand_routes.routes.xml',
#    lanewise=True, addlfiles=['data/networks/smallnet/smallnet_additionals.add.xml', 'data/networks/smallnet/tls_output.add.xml']
#)

#with realistic traffic lights
sn = SumoNetwork(
    'data/networks/smallnet_real/smallnet_real.net.xml', routefile='data/networks/smallnet_real/smallnet_real_rand_routes.routes.xml',
    lanewise=True, addlfiles=['data/networks/smallnet_real/smallnet_real_additionals.add.xml', 'data/networks/smallnet_real/tls_output.add.xml']
)


#sn.run()
#sn.load_data_to_graph()
#graph = sn.get_graph()
# Out:
# 2018-07-09 16:26:54,978 matplotlib.font_manager DEBUG    Using fontManager instance from /home/simon/.cache/matplotlib/fontList.json
# 2018-07-09 16:26:55,219 matplotlib.backends DEBUG    backend module://ipykernel.pylab.backend_inline version unknown
# 2018-07-09 16:26:55,560 matplotlib.backends DEBUG    backend module://ipykernel.pylab.backend_inline version unknown

# %%
#import os

# %%
#os.path.dirname(sn.netfile)

# %%
#os.path.join(os.path.dirname(sn.netfile), 'output/one_intersection_e1_output.xml')

# %%
#graph.nodes('detectors')['1/3to1/2_0']['e1_1-3to1-2_0_1']['pos']
#os.path.join(os.path.dirname(sn.netfile), graph.nodes('detectors')[self.sumolib_in_lane.getID])
#os.path.join(os.path.dirname(sn.netfile), graph.nodes('detectors')['1/3to1/2_0']['e1_1-3to1-2_0_0']['file'])

# %%
from trafficgraphnn.liumethod import LiuEtAlRunner
from trafficgraphnn.liumethod import LiuIntersection
from trafficgraphnn.liumethod import LiuLane

test_run = LiuEtAlRunner(sn)

max_num_phase = test_run.get_max_num_phase(end_time = 2000)
print('max_num_phase:', max_num_phase)
test_run.run_up_to_phase(max_num_phase)
test_run.plot_results_every_lane(show_plot = True, show_infos = False)


#test_run.run_up_to_phase(28)
#test_run.plot_results_every_lane()

#lane= '1/3to1/2_2'

#current_lane = LiuLane(lane, graph)

#for num_phase in range( 1, 30):
#    start, end, curr_detector_occupancy, curr_nVehEntered, curr_e1_stopbar, curr_e1_adv_detector, curr_e2_detector = current_lane.parse_cycle_data(num_phase)
#    current_lane.breakpoint_identification(num_phase, start, end, curr_detector_occupancy, curr_nVehEntered, curr_e1_stopbar, curr_e1_adv_detector)
#    current_lane.queue_estimate(num_phase, start, end, curr_e1_adv_detector)
#    print('############', current_lane.get_ground_truth_queue(num_phase, start, end, curr_e2_detector))
#    mape = current_lane.get_MAPE()
#    print('MAPE: ', mape)
    
#current_lane.plot()
# Out:
# max_num_phase: 20
# Running estimation for every lane in every intersection in phase 1
# Running estimation for every lane in every intersection in phase 2
# Running estimation for every lane in every intersection in phase 3
# Running estimation for every lane in every intersection in phase 4
# Running estimation for every lane in every intersection in phase 5
# Running estimation for every lane in every intersection in phase 6
# Running estimation for every lane in every intersection in phase 7
# Running estimation for every lane in every intersection in phase 8
# Running estimation for every lane in every intersection in phase 9
# Running estimation for every lane in every intersection in phase 10
# Running estimation for every lane in every intersection in phase 11
# Running estimation for every lane in every intersection in phase 12
# Running estimation for every lane in every intersection in phase 13
# Running estimation for every lane in every intersection in phase 14
# ...

# %%
MAPE_IO, MAPE_liu = test_run.get_total_MAPE_per_net()
print('MAPE_IO:', MAPE_IO)
print('MAPE_liu:', MAPE_liu)
#lane_ids = [liulane.sumolib_lane.getID() for liulane in self.liu_lanes]
# Out:
# MAPE_IO: 0.2593544050885678
# MAPE_liu: 0.4020673425531581

# %%
#sn.graph.node('1/2to2/2_1')

# %%
#sn.net.getLane('1/2to2/2_1')
#sn.net.getEdge('1/2to2/2_1')
#graph.edges['0/2to1/2_0', '1/2to1/1_0']

# %%
#lane = '0/0to0/1_0'
#lane_out = '0/1to0/2_0'
#graph.edges[(lane, lane_out)]['switch_times']
